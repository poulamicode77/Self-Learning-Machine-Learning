# %%
import numpy as np 

#handling numbers in array
a = np.array([1,2,3])
b = np.array([[1],[2],[3]])
print(a) # 'a' is a 1D array
print(b) # 'b' is a 2D array
# Out:
# [1 2 3]
# [[1]
#  [2]
#  [3]]
