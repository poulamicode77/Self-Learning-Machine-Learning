# %%
import numpy as np 

#handling numbers in array
a = np.array([1,2,3])
b = np.array([[1],[2],[3]])
print(a) # 'a' is a 1D array
print(b) # 'b' is a 2D array
# Out:
# [1 2 3]
# [[1]
#  [2]
#  [3]]

# %%
print(a.shape) # a is a 1D array 
print(b.shape) # b is a 2D array and has 3 rows 1 column
# Out:
# (3,)
# (3, 1)
